# %% [markdown]
# ### Importing Libraries

# %%
import os
import pandas as pd

# %% [markdown]
# ### Checking Current Working Directory

# %%
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\harsh\\Desktop\\python-assignment-level2-6ed53b4e828af18bc24b1770a3a3e3e70706e785'

# %% [markdown]
# ### Creating Base & Data Directory

# %%
BASE_DIR  = os.path.dirname(cwd)
DATA_DIR = os.path.join(BASE_DIR,'.\\python-assignment-level2-6ed53b4e828af18bc24b1770a3a3e3e70706e785\\input_data\\starter')
DATA_DIR
# Out:
# 'C:\\Users\\harsh\\Desktop\\.\\python-assignment-level2-6ed53b4e828af18bc24b1770a3a3e3e70706e785\\input_data\\starter'

# %%
os.listdir(DATA_DIR)
# Out:
# ['customers.csv', 'products.csv', 'transactions']

# %% [markdown]
# ### Loading Data From CSV Files

# %%
# Loading Data From Customers.csv

my_data1 = os.path.join(DATA_DIR,'customers.csv')
customers_data = pd.read_csv(my_data1)
customers_data.head()
# Out:
#   customer_id  loyalty_score
# 0          C1              7
# 1          C2              4
# 2          C3              8
# 3          C4              5
# 4          C5              7

# %%
# Loading Data From Products.csv

my_data2 = os.path.join(DATA_DIR,'products.csv')
product_data = pd.read_csv(my_data2)
product_data.head()
# Out:
#   product_id product_description product_category
# 0        P01           detergent            house
# 1        P02        kitchen roll            house
# 2        P03          bin liners            house
# 3        P04          shower gel            house
# 4        P05     scented candles            house

# %%
my_data3 = os.path.join(DATA_DIR,'transactions\d=2018-12-01\\transactions.json')
print(my_data3)
transaction_data = pd.read_json(my_data3,lines=True)
transaction_data
# Out:
# C:\Users\harsh\Desktop\.\python-assignment-level2-6ed53b4e828af18bc24b1770a3a3e3e70706e785\input_data\starter\transactions\d=2018-12-01\transactions.json
#    customer_id                                             basket  \
# 0           C3  [{'product_id': 'P26', 'price': 1545}, {'produ...
# 1          C11  [{'product_id': 'P02', 'price': 1650}, {'produ...
# 2          C21  [{'product_id': 'P05', 'price': 594}, {'produc...
# 3          C31  [{'product_id': 'P34', 'price': 983}, {'produc...
# 4          C37  [{'product_id': 'P63', 'price': 1559}, {'produ...
# 5          C42             [{'product_id': 'P22', 'price': 1021}]
# 6          C47  [{'product_id': 'P60', 'price': 437}, {'produc...
# 7          C50              [{'product_id': 'P39', 'price': 773}]
# 8          C56  [{'product_id': 'P35', 'price': 1750}, {'produ...
# 9          C62  [{'product_id': 'P59', 'price': 1924}, {'produ...
# 10         C76  [{'product_id': 'P23', 'price': 162}, {'produc...
# 11         C95  [{'product_id': 'P30', 'price': 1625}, {'produ...
# 12         C96  [{'product_id': 'P22', 'price': 1390}, {'produ...
# 13         C97              [{'product_id': 'P57', 'price': 180}]
# 14         C98             [{'product_id': 'P59', 'price': 1901}]
# 15        C102             [{'product_id': 'P58', 'price': 1617}]
# 16        C105  [{'product_id': 'P57', 'price': 1281}, {'produ...
# 17        C107                [{'product_id': 'P61', 'price': 3}]
# 18        C125             [{'product_id': 'P09', 'price': 1330}]
# 19        C129  [{'product_id': 'P09', 'price': 1360}, {'produ...
# 20        C130  [{'product_id': 'P04', 'price': 515}, {'produc...
# 21        C135  [{'product_id': 'P46', 'price': 1158}, {'produ...
#
#        date_of_purchase
# 0   2018-12-01 06:26:00
# 1   2018-12-01 21:19:00
# 2   2018-12-01 10:09:00
# 3   2018-12-01 14:23:00
# 4   2018-12-01 07:08:00
# 5   2018-12-01 18:18:00
# 6   2018-12-01 07:38:00
# 7   2018-12-01 13:55:00
# 8   2018-12-01 04:10:00
# 9   2018-12-01 21:04:00
# 10  2018-12-01 05:15:00
# 11  2018-12-01 20:10:00
# 12  2018-12-01 08:46:00
# 13  2018-12-01 02:59:00
# 14  2018-12-01 05:19:00
# 15  2018-12-01 06:33:00
# 16  2018-12-01 10:02:00
# 17  2018-12-01 06:42:00
# 18  2018-12-01 19:45:00
# 19  2018-12-01 10:38:00
# 20  2018-12-01 20:54:00
# 21  2018-12-01 22:49:00

# %% [markdown]
# # Concatinating All Dataframes

# %%
Final_df = pd.concat([customers_data,product_data,transaction_data])
Final_df
# Out:
#    customer_id  loyalty_score product_id product_description product_category  \
# 0           C1            7.0        NaN                 NaN              NaN
# 1           C2            4.0        NaN                 NaN              NaN
# 2           C3            8.0        NaN                 NaN              NaN
# 3           C4            5.0        NaN                 NaN              NaN
# 4           C5            7.0        NaN                 NaN              NaN
# ..         ...            ...        ...                 ...              ...
# 17        C107            NaN        NaN                 NaN              NaN
# 18        C125            NaN        NaN                 NaN              NaN
# 19        C129            NaN        NaN                 NaN              NaN
# 20        C130            NaN        NaN                 NaN              NaN
# 21        C135            NaN        NaN                 NaN              NaN
#
#                                                basket     date_of_purchase
# 0                                                 NaN                  NaN
# 1                                                 NaN                  NaN
# 2                                                 NaN                  NaN
# 3                                                 NaN                  NaN
# 4                                                 NaN                  NaN
# ..                                                ...                  ...
# 17                [{'product_id': 'P61', 'price': 3}]  2018-12-01 06:42:00
# 18             [{'product_id': 'P09', 'price': 1330}]  2018-12-01 19:45:00
# 19  [{'product_id': 'P09', 'price': 1360}, {'produ...  2018-12-01 10:38:00
# 20  [{'product_id': 'P04', 'price': 515}, {'produc...  2018-12-01 20:54:00
# 21  [{'product_id': 'P46', 'price': 1158}, {'produ...  2018-12-01 22:49:00
#
# [223 rows x 7 columns]

# %% [markdown]
# # Saving the final Dataframe into CSV

# %%
Final_df.to_csv('./Final_Customer_Data.csv')
